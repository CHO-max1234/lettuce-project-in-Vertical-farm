# %% [markdown]
# <a href="https://colab.research.google.com/github/CHO-max1234/lettuce-project-in-Vertical-farm/blob/main/4_scale_%EC%9E%A1%EA%B8%B0_4%EC%A0%90_anchor_%EA%B8%B0%EB%B0%98_scale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #✔ 최종 파이프라인 (윗면 2작기)
# 1. p1~p4 anchor 검출 (윗면 기준)<< 이 페이지에선 1번
# - QC: matched_count=4 우선 사용
# - 실패 시 overlay로 확인만
# 2. slot-center extrapolation
# - p1→p2: top edge
# - p4→p3: bottom edge
# - 여기서 t/b row 생성
# - x 방향 pitch로 t1~t4 / b1~b4 생성
# 3. lettuce-seg
# - 개체 중심점(cx, cy)
# 4. slot assignment
# - 각 lettuce → nearest slot center
# 5. QC
# - 거리 threshold
# - edge_partial
# - missing / multi-slot
# - (이후에 crop or 지표)
